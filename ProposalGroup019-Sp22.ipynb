# %% [markdown]
# # COGS 118A- Project Proposal

# %% [markdown]
# ### Peer Review
#
# You will all have an opportunity to look at the Project Proposals of other groups to fuel your creativity and get more ideas for how you can improve your own projects.
#
# Both the project proposal and project checkpoint will have peer review.

# %% [markdown]
# # Names
#
#
# - David Thai
# - Nicholas Nassour
# - Daniel Byers
# - Yu Pan
# - Jordyn Ohashi

# %% [markdown]
# # Abstract
# Our project's goal is to be able to successfully analyze 4 sectors in the stock market correctly. We are going to look at the trends of the top 5 tech, real estate, retail, pharmaceuticals, and car company stocks. We believe that these top five per sector have a lot of potential to grow and are continuing to grow day by day. As a result of this, we want to see if day trading flags, sentiment analysis of news headlines, flight data, and opening and closing values are able to give us a deeper analysis of these stocks. We will be looking at how these variables affect our stocks by sector and if there are any relationships across the sector. This will be compared to Yahoo Finances' stock rating for the day. Metrics of success will be being able to classify successfully the 5 metrics we list as actions that will move the particular stocks up or down correctly. Moreover, we believe that this will allow us to build predictive models of these stocks. While this is a plus, our focus is to be able to use our variables to classify the actions of investors and the world to determine if particular sectors will perform better or worse on that particular day.

# %% [markdown]
# # Background
#
# Analyzing the stock market is sometimes considered to be a random process with rises and falls that are unpredictable. The belief is that there is no real way to predict the trends that occur as the ups and downs are similar to that of a random walk in a neighborhood and there is no accurate prediction that can be made. [<sup>1</sup>](#fn1)
# However, time and time again, people attempt to develop models that analyze current and past trends in the market to accurately predict what their future trades should be. One such example is commonly referred to as the “Buffet indicator,” a model used to indicate the relative value of specific stock to the entirety of the market and assert whether or not it is undervalued or overpriced.[<sup>2</sup>](#fn2) With a lack of expertise in financial or economic sector, we believed that creating a machine learning model to analyze trends may not be entirely reliable. Therefore, when considering our own attempt to see if we could somehow game the stock market system, we shifted our focus from strictly analyzing how to notice internal trends in the market and what the next move might be to instead studying outside factors, such as daily news sentiment, and the impact they have on the system itself. News is just one factor but it plays an important role in determining the stock market shift as it heavily influences emotional traders who might be willing to purchase stock during good news while dumping their stock during bad news.[<sup>3</sup>](#fn3) For these reasons, our goal aims to determine how well we can predict possible buy and sell points by estimating the weight that outside factors have on the market and their combined scores.

# %% [markdown]
# # Problem Statement
#
# The problem that our group will be tackling is looking for what is the most influential factor in the way stocks react. We will be taking in a number of features into account and using them to classify whether people should buy or sell. Each of the features will be put into a vector and we will be using feature selection to understand the feature should hold the most weight. The feature that is the most influential on getting the correct classification will be the factor we take as the most important to understanding how stocks react.

# %% [markdown]
# # Data
#
#    Our initial hypothesis on how we should answer our problem statement was through factors like other stocks, inflation rates, news headlines, and flight data. We still have to narrow down the scope of the factors we’re considering, but ideally we would like to start with price data for an index fund. Index funds represent a more well rounded perspective of public sentiment, which we feel will be crucial for seeing how an event can have a perceived impact on stock prices.
#
# An example of an ideal dataset looks like this one we found on Kaggle: S&P 500 stock data | Kaggle. It has the name, volume, open, high, low, and close price for the S&P 500 Index fund from Febuary 2013 - February 2018 (1,825 Observations). Ideally we would like this dataset to be bigger, but this is a good start to what we are imagining our dataset to look like. We hope to use this dataset in combination with TA-lib (python package for technical analysis) to see how trends in the price data could potentially be indicators of future price behavior.
#
# We could also potentially create our own stock price datasets using an API like Alpha Vantage, but we have yet to discuss this further once we get a better understanding of the problem we’re trying to tackle.
#
# As mentioned before, we also want news headlines across a period of time in the US that could help us gauge public sentiment. We want this dataset to have headlines from different sources that we could then use sentiment analysis and NLP to map onto price data to see potential correlations. Our first impression of this would be this dataset from Harvard: A Million News Headlines - Datta-Barsha (harvard.edu), which includes one million observations of just the headline and date.
#
# We will consider further what other factors we would like to include in this comparison, but ideally these are the two we would like to start with.

# %% [markdown]
# # Proposed Solution
#
# Our solution to solve the proposed problem is by classifying the stock prices data. We plan to train a model based on the average daily news sentiment and the price of past S&P 500 index to predict the trends of future market trends, thus providing the user a suggestion to purchase or sell.
#
# To make this decision, we will create a specific database such that it consists of a series of vectors. Each vector contains information about the movement of a stock and the average news sentiment of a day(we might adjust the length of this time period if necessary). The candle stick provides us with valuable information about the movement of the stock and will be translated into five numbers shown in the graph below.
#
# ![Cogs118a1.PNG](attachment:Cogs118a1.PNG)
#
# We will also include other factors that we consider as relevant. For example, we plan to include the movement of S&P 500 in that same vector so that we can adapt our model to the systemic risk of the market(https://www.kaggle.com/datasets/hanseopark/sp-500-stocks-value-with-financial-statement).
#
# With this dataset, we can train our model by feature extraction, where we use the average price of the stock in the next six months as the labels to indicate the performance of our recommendations.

# %% [markdown]
# # Evaluation Metrics
#
# As stated in the solution section, we will judge the performance of our model by looking at the average price of the stock in the next six month after our recommendation of buy or sell. If the price is averagely higher than that at the time we make the buy recommendation, ![Cogs118a2.PNG](attachment:Cogs118a2.PNG)
# With this metric, we will have to obtain our own labels by calculating the average price of a stock in the six months after the suggestion that our model has made.
#
# However, a more convenient metric is considered by us as a backup plan. We find that most financial websites such as yahoo finance provides its audience with a rating for a stock (strong buy, hold, strong sell, etc.). This can serve as labels that we can directly use in training. We can request this data with their API(https://www.yahoofinanceapi.com).

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# It should be clear that none of us are financial or quantitative trading experts, so the results of this project should be considered with a grain of salt. Our results should in no way be interpreted as financial advice and that should be clear in the description of our project. We are using publicly available information from the stock market that has been recorded over the past few years and should not be a violation of privacy. Along with the sentiment analysis information that is provided, there is nothing regarding any personal data such as names, birthdays, familiar history, etc.

# %% [markdown]
# # Team Expectations

# %% [markdown]
# - Attempt to reply within a fair time frame either through text message or discord when a group member sends out a concern
# - Split up work fairly which will be determined by the amount of time necessary to complete each section
# - We will switch off work between group members if we decide different sections may be easier for different people
# - Take a majority vote for determining decisions as to how we might shift our focus on the project or finding a given solution
# - Work together to help a group member if they are unable to meet deadlines, if they may have fallen behind, without forcing them to submit their work late

# %% [markdown]
# # Project Timeline Proposal

# %% [markdown]
# Replace this with something meaningful that is appropriate for your needs. It doesn't have to be something that fits this format.  It doesn't have to be set in stone... "no battle plan survives contact with the enemy". But you need a battle plan nonetheless, and you need to keep it updated so you understand what you are trying to accomplish, who's responsible for what, and what the expected due dates are for each item.
#
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# | 4/29  |  1 PM |  Finalize project plan/scope and identify necessary tools/ types of data  | What kind of data do we need and what requirements does it have to meet?; What kind of cleaning do we need to do?
#  |
# | 5/4  |  10 AM |  Finalize datasets we will be working with | Distribute data cleaning work among group members; What kind of model will we be using? |
# | 5/11  | 10 AM  | Perform EDA and begin training model  | What kind of statistics do we need to know?; Review math with teaching staff|
# | 5/18  | 6 PM  |Improve model performance / Review progress so far | Do we need to pivot/edit project path?; How can we improve our model’s performance?
#    |
# | 5/23  | 12 PM  | Prepare presentation and finalize code | Discuss/edit project code; Complete project; Distribute work for preparing final presentation |
# | 5/30  | 12 PM  | Finish and submit final project | Discuss/edit full project |

# %% [markdown]
# # Footnotes
#
#
#
# <span id="fn1"> 1. Cootner, Paul H. (1964). The random character of stock market prices. MIT Press. ISBN 978-0-262-03009-0.</span>
#
# <span id="fn1"> 2. Mislinski, Jill (3 March 2020). "Market Cap to GDP: An Updated Look at the Buffett Valuation Indicator". www.advisorperspectives.com </span>
#
# <span id="fn1"> 3. Chan, Wesley S. ” Stock price reaction to news and no-news: drift and reversal after headlines. ” Journal of Financial Economics 70.2 (2003): 223-260. </span>
